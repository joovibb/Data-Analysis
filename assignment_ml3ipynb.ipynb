# %% [markdown]
# <a href="https://colab.research.google.com/github/joovibb/Data-Analysis/blob/main/assignment_ml3ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#opening dataset
import pandas as pd

df = pd.read_csv("/content/Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#null values check
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

df['State'] = le.fit_transform(df['State'])

# %%
X = df.iloc[:,:-1].values
y =df['Profit']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
#Multiple Linear Regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
r2 = r2_score(y_test, y_pred)
print(f"(Accuracy)R2 score: {r2}")
print(f"model score")
lr.score(X_train,y_train)
# Out:
# Mean Squared Error: 247792385.71658397
# (Accuracy)R2 score: 0.8635659846974574
# model score
# 0.9725475917900681

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
regressor = SGDRegressor(max_iter=1000, tol=1e-3)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2): {r2}")
# Out:
# Mean Squared Error (MSE): 247181681.38980085
# R-squared (R2): 0.8639022373358293

# %%
#Linear Regression
import seaborn as sns
import matplotlib.pyplot as plt
X = df['Marketing Spend']
y =df['Profit']
sns.barplot(x=df['State'],y=df["R&D Spend"])
plt.show()

# %%
sns.violinplot(data=df,color='blue')
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(),cmap='coolwarm',annot=True,)
# Out:
# <Axes: >

# %%
#decision tree
X = df.iloc[:,:-1]
y =df['Profit']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor()
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
X_train.head()
# Out:
#     R&D Spend  Administration  Marketing Spend  State
# 0   165349.20       136897.80        471784.10      2
# 33   55493.95       103057.49        214634.81      1
# 10  101913.08       110594.11        229160.95      1
# 4   142107.34        91391.77        366168.42      1
# 28   66051.52       182645.56        118148.20      1

# %%
y_pred = regressor.predict(X)
mse = mean_squared_error(y, y_pred)
print(f"Mean Squared Error: {mse}")
r2 = r2_score(y, y_pred)
print(f"R-squared (R2): {r2}")
print(f"model score")
regressor.score(X_train,y_train)
# Out:
# Mean Squared Error: 26510606.63133801
# R-squared (R2): 0.9833486172911555
# model score
# 1.0

# %%
#support vector regression
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
regresso = SVR()

# %%
regresso.fit(X_train, y_train)
y_pred = regresso.predict(X_test)
mse = mean_squared_error(y_test, y_pred)

# %%
print(f"Mean Squared Error: {mse}")
r2 = r2_score(y_test, y_pred)
print(f"R-squared (R2): {r2}")
print(f"model score")
regresso.score(X_train,y_train)
# Out:
# Mean Squared Error: 1478778137.1511111
# R-squared (R2): -0.17907989219420495
# model score
# -0.0031531651797302995

# %%
X_train
# Out:
#     R&D Spend  Administration  Marketing Spend  State
# 0   165349.20       136897.80        471784.10      2
# 33   55493.95       103057.49        214634.81      1
# 10  101913.08       110594.11        229160.95      1
# 4   142107.34        91391.77        366168.42      1
# 28   66051.52       182645.56        118148.20      1
# 15  114523.61       122616.84        261776.23      2
# 8   120542.52       148718.95        311613.29      2
# 20   76253.86       113867.30        298664.47      0
# 2   153441.51       101145.55        407934.54      1
# 48     542.05        51743.15             0.00      2
# 9   123334.88       108679.17        304981.62      0
# 30   61994.48       115641.28         91131.24      1
# 12   93863.75       127320.38        249839.44      1
# 46    1315.46       115816.21        297114.46      1
# 27   72107.60       127864.55        353183.81      2
# 21   78389.47       153773.43        299737.29      2
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score

clf = DecisionTreeRegressor(random_state=44)
clf = clf.fit(X_train,y_train)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
mse1 = mse = mean_absolute_error(y_test, y_pred)
print(f'mean_absolute_error: {mse1}')
r2 = r2_score(y_test, y_pred)
print(f"(Accuracy)R2 score: {r2}")
# Out:
# Mean Squared Error: 190443199.23592
# mean_absolute_error: 11882.170000000002
# (Accuracy)R2 score: 0.8845861176606399
